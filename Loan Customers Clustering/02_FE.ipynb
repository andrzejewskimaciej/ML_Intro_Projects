# %%
import pandas as pd 
import numpy as np 
from pandas.tseries.offsets import DateOffset
import seaborn as sns 
import matplotlib.pyplot as plt 
import re

# %% [markdown]
# Wczytanie danych

# %%
df=pd.read_csv("data/CleanedKaggle/financial_loan_cleaned.csv")

# %%
df
# Out:
#       address_state emp_title home_ownership  issue_date  \
# 0                GA     Other           RENT  11-02-2021
# 1                CA     Other           RENT  01-01-2021
# 2                CA     Other           RENT  05-01-2021
# 3                TX     Other       MORTGAGE  25-02-2021
# 4                IL     Other       MORTGAGE  01-01-2021
# ...             ...       ...            ...         ...
# 38571            NJ     Other       MORTGAGE  11-07-2021
# 38572            NY     Other           RENT  11-10-2021
# 38573            CA     Other           RENT  11-09-2021
# 38574            NY     Other           RENT  11-10-2021
# 38575            NY     Other           RENT  11-07-2021
#
#       last_credit_pull_date last_payment_date  loan_status next_payment_date  \
# 0                13-09-2021        13-04-2021  Charged Off        13-05-2021
# 1                14-12-2021        15-01-2021   Fully Paid        15-02-2021
# 2                12-12-2021        09-01-2021  Charged Off        09-02-2021
# 3                12-12-2021        12-03-2021   Fully Paid        12-04-2021
# 4                14-12-2021        15-01-2021   Fully Paid        15-02-2021
# ...                     ...               ...          ...               ...
# 38571            16-05-2021        16-05-2021      Current        16-06-2021
# 38572            16-04-2021        16-05-2021      Current        16-06-2021
# 38573            16-05-2021        16-05-2021      Current        16-06-2021
# 38574            16-05-2021        16-05-2021      Current        16-06-2021
# 38575            16-05-2021        16-05-2021      Current        16-06-2021
#
#        purpose verification_status  ...  last_credit_pull_weekday  \
# 0          car     Source Verified  ...                         0
# 1          car     Source Verified  ...                         1
# 2          car        Not Verified  ...                         6
# 3          car     Source Verified  ...                         6
# 4          car            Verified  ...                         1
# ...        ...                 ...  ...                       ...
# 38571  wedding            Verified  ...                         6
# 38572  wedding            Verified  ...                         4
# 38573  wedding            Verified  ...                         6
# 38574  wedding            Verified  ...                         6
# 38575  wedding            Verified  ...                         6
#
#        last_payment_year  last_payment_month  last_payment_day  \
# 0                   2021                   4                13
# 1                   2021                   1                15
# 2                   2021                   1                 9
# 3                   2021                   3                12
# 4                   2021                   1                15
# ...                  ...                 ...               ...
# 38571               2021                   5                16
# 38572               2021                   5                16
# 38573               2021                   5                16
# 38574               2021                   5                16
# 38575               2021                   5                16
#
#        last_payment_weekday  next_payment_year  next_payment_month  \
# 0                         1               2021                   5
# 1                         4               2021                   2
# 2                         5               2021                   2
# 3                         4               2021                   4
# 4                         4               2021                   2
# ...                     ...                ...                 ...
# 38571                     6               2021                   6
# 38572                     6               2021                   6
# 38573                     6               2021                   6
# 38574                     6               2021                   6
# 38575                     6               2021                   6
#
#        next_payment_day  next_payment_weekday  term_months
# 0                    13                     3           60
# 1                    15                     0           36
# 2                     9                     1           36
# 3                    12                     0           60
# 4                    15                     0           36
# ...                 ...                   ...          ...
# 38571                16                     2           60
# 38572                16                     2           60
# 38573                16                     2           60
# 38574                16                     2           60
# 38575                16                     2           60
#
# [38576 rows x 37 columns]

# %% [markdown]
# ## States

# %%
df['address_state'].unique().shape
# Out:
# (50,)

# %% [markdown]
# grupujemy stany na północne i południowe

# %%
North = {'CO', 'CT', 'DE', 'ID', 'IL', 'IA', 'IN', 'ME', 'MD', 'MA',
         'MI', 'MN', 'MT', 'NE', 'NH', 'NJ', 'ND', 'NV', 'NY', 'OH',
         'OR', 'PA', 'RI', 'SD', 'UT', 'VT', 'WA', 'WI', 'WY'}
South = {'AL', 'AK', 'AZ', 'AR', 'CA', 'FL', 'GA', 'HI', 'KS', 'KY',
         'LA', 'MO', 'MS', 'NC', 'NM', 'OK', 'SC', 'TN', 'TX', 'VA', 'WV'}
north_south = {
    "North": North,
    "South": South
}

def north_south_apply(x,north_south): 
    if x in north_south['North']:
        return "North" 
    else:
        return "South"

# %%
df['north_south_address']=df['address_state'].apply(lambda x: north_south_apply(x,north_south))

# %%
df[['address_state', 'north_south_address']].value_counts()
# Out:
# address_state  north_south_address
# CA             South                  6894
# NY             North                  3701
# FL             South                  2773
# TX             South                  2664
# NJ             North                  1822
# IL             North                  1486
# PA             North                  1482
# VA             South                  1375
# GA             South                  1355
# MA             North                  1310
# OH             North                  1188
# MD             North                  1027
# AZ             South                   833
# WA             North                   805
# CO             North                   770
# NC             South                   759
# CT             North                   730
# MI             North                   685
# MO             South                   660
# MN             North                   592
# NV             North                   482
# SC             South                   464
# WI             North                   446
# OR             North                   436
# AL             South                   432
# LA             South                   426
# KY             South                   320
# OK             South                   293
# KS             South                   260
# UT             North                   252
# AR             South                   236
# DC             South                   214
# RI             North                   196
# NM             South                   183
# HI             South                   170
# WV             South                   167
# NH             North                   161
# DE             North                   110
# MT             North                    79
# WY             North                    79
# AK             South                    78
# SD             North                    63
# VT             North                    54
# MS             South                    19
# TN             South                    17
# IN             North                     9
# ID             North                     6
# NE             North                     5
# IA             North                     5
# ME             North                     3
# Name: count, dtype: int64

# %% [markdown]
# ## Purpose
# zmienna celu, czy pieniądze zostaną wydane na życie prywatne, na sprawy finansowe (w tym własny biznes) czy na coś innego

# %%
df['purpose'].unique()
# Out:
# array(['car', 'credit card', 'Debt consolidation', 'educational',
#        'home improvement', 'house', 'major purchase', 'medical', 'moving',
#        'other', 'renewable_energy', 'small business', 'vacation',
#        'wedding'], dtype=object)

# %%
def purpose_clutsering(x): 
    # to discuss
    life=['car','home','home improvement','house','medical','moving','vacation', 'wedding','major purchase', 
         'renewable_energ']
    finance=['credit card','Debt consolidation','small business']
    if x in life: 
        return 'life' 
    elif x in finance: 
        return 'finance' 
    else: 
        return 'Other'

# %%
df['purpose_clustered']=df['purpose'].apply(purpose_clutsering)

# %%
df[['purpose','purpose_clustered']].value_counts()
# Out:
# purpose             purpose_clustered
# Debt consolidation  finance              18214
# credit card         finance               4998
# other               Other                 3824
# home improvement    life                  2876
# major purchase      life                  2110
# small business      finance               1776
# car                 life                  1497
# wedding             life                   928
# medical             life                   667
# moving              life                   559
# house               life                   366
# vacation            life                   352
# educational         Other                  315
# renewable_energy    Other                   94
# Name: count, dtype: int64

# %% [markdown]
# ## Date

# %% [markdown]
# sprawdzenie, czy kredyt został wydany po czy przed ostatnim pobraniem informacji kredytowej o klienci

# %%
df['issue_date'] = pd.to_datetime(df['issue_date'], format='%d-%m-%Y')
df['last_credit_pull_date'] = pd.to_datetime(df['last_credit_pull_date'], format='%d-%m-%Y')
df['daysdiff_issue_pull'] = (df['issue_date'] - df['last_credit_pull_date']).dt.days
df['pull_after_issue']=np.where(df['daysdiff_issue_pull']>0,1,0)

# %% [markdown]
# liczba dni pomiędzy kolejnymi płatnościami

# %%
df['next_payment_date'] = pd.to_datetime(df['next_payment_date'], format='%d-%m-%Y')
df['last_payment_date'] = pd.to_datetime(df['last_payment_date'], format='%d-%m-%Y')
df['last_next_diff']=(df['next_payment_date']-df['last_payment_date']).dt.days

# %%
df.last_next_diff.value_counts()
# Out:
# last_next_diff
# 31    23680
# 30    11765
# 28     3131
# Name: count, dtype: int64

# %%
df['loan_status'].unique()
# Out:
# array(['Charged Off', 'Fully Paid', 'Current'], dtype=object)

# %%
def date_fixer(x,y): 
    if x=='Fully Paid':
        return 0 
    else: 
        return y

# %%
df['last_next_diff'] = df.apply(
    lambda row: date_fixer(row['loan_status'],
                                     row['last_next_diff']),
    axis=1
)

# %% [markdown]
# albo ktoś już spłacił, albo płaci co miesiąc; nie będziemy korzystać z tej kolumny

# %%
df['last_next_diff'].unique()
# Out:
# array([30,  0, 31, 28], dtype=int64)

# %% [markdown]
# ile czasu zostało do końca spłaty

# %%
df['end_date'] = df.apply(
    lambda row: row['issue_date'] + DateOffset(months=row['term_months']),
    axis=1
)
df['time_to_last_payment']=(df['end_date']-df['next_payment_date']).dt.days 

df['time_to_last_payment'] = df.apply(
    lambda row: date_fixer(row['loan_status'],
                                     row['time_to_last_payment']),
    axis=1
)

# %% [markdown]
# ## Jobs
# pogrupowanie ze względu na rodzaj wykonywanej pracy

# %%
df['emp_title'].value_counts()[50:200]
# Out:
# emp_title
# Columbia University                21
# American Express                   21
# Department of Homeland Security    21
# PricewaterhouseCoopers             20
# Department of Veterans Affairs     20
#                                    ..
# Charles Schwab                     10
# Yale University                    10
# URS Corporation                    10
# Costco                             10
# Rite Aid                           10
# Name: count, Length: 119, dtype: int64

# %%
categories = {
    "Tech/Telecom": [r"tech", r"software", r"information", r"it", r"comcast", r"verizon", r"at[\\s&]*t", r"accenture", r"saic", r"northrop", r"lockheed", r"booz", r"sprint", r"intel", r"microsoft", r"apple", r"google", r"oracle", r"cisco", r"ibm", r"hp", r"dell", r"digital", r"data"],
    "Finance": [r"bank", r"finance", r"financial", r"fidelity", r"tiaa", r"credit", r"invest", r"citigroup", r"wells", r"chase", r"hartford", r"visa", r"mastercard", r"capital [oO]ne", r"goldman", r"morgan", r"accountant", r"cpa", r"auditor", r"insurance"],
    "Military": [r"air force", r"\\barmy\\b", r"\\bnavy\\b", r"\\bmarine", r"usaf", r"u\\.s\\.\\s*army", r"u\\.s\\.\\s*navy", r"u\\.s\\.\\s*air", r"coast guard", r"military", r"department of defense", r"\\bdod\\b"],
    "Education": [r"school", r"university", r"college", r"district", r"teacher", r"professor", r"education", r"institute"],
    "Healthcare": [r"hospital", r"health", r"kaiser", r"medical", r"clinic", r"pharma", r"nurse", r"doctor", r"healthcare", r"patient"],
    "Retail/Hospitality": [r"walmart", r"costco", r"target", r"home depot", r"lowe", r"walgreens", r"macy", r"starbucks", r"marriott", r"hotel", r"restaurant", r"amazon", r"retail", r"grocery"],
    "Transportation/Logistics": [r"airline", r"aviation", r"faa", r"airport", r"transport", r"logistics", r"freight", r"ups", r"fedex", r"truck", r"usps", r"postal service"],
    "Government/Civil Service": [r"federal", r"department of", r"\\bcity of\\b", r"\\bcounty\\b", r"government", r"homeland", r"irs", r"public", r"state of", r"court", r"postal"],
    "Consulting/Professional Services": [r"consult", r"advisor", r"bain", r"mckinsey", r"deloitte", r"pwc", r"pricewaterhouse", r"ey", r"kpmg", r"booz allen"],
    "Self-Employed": [r"\\bself\\b", r"self[-\\s]?employed", r"freelance", r"owner", r"proprietor", r"entrepreneur"],
    "Manufacturing/Engineering": [r"engineering", r"engineer", r"mfg", r"manufacturing", r"plant", r"production", r"automotive", r"boeing"],
    "Energy/Utilities": [r"energy", r"utility", r"power", r"electric", r"gas", r"oil", r"solar"],
    "Legal/Law": [r"law", r"legal", r"attorney", r"lawyer", r"paralegal"],
}
def classify(title):
    t = title.lower()
    for cat, patterns in categories.items():
        for p in patterns:
            if re.search(p, t):
                return cat
    return "Other"

df["emp_category"] = df["emp_title"].apply(classify)

# %%
df["emp_category"].value_counts()
# Out:
# emp_category
# Other                               34580
# Tech/Telecom                         2417
# Finance                               530
# Retail/Hospitality                    302
# Transportation/Logistics              217
# Military                              180
# Government/Civil Service              136
# Healthcare                             56
# Education                              46
# Manufacturing/Engineering              31
# Consulting/Professional Services       30
# Self-Employed                          28
# Energy/Utilities                       23
# Name: count, dtype: int64

# %% [markdown]
# ## Skewness
# redukcja skośności

# %%
sns.histplot(df.loan_amount)
plt.show()
sns.histplot(df.installment)
plt.show()
sns.histplot(df.total_acc)
plt.show()
sns.histplot(df.total_payment)
plt.show()

# %%
sns.histplot(np.sqrt(df.loan_amount))
plt.show()
sns.histplot(np.sqrt(df.installment))
plt.show()
sns.histplot(np.sqrt(df.total_acc))
plt.show()
sns.histplot(np.sqrt(df.total_payment))
plt.show()

# %%
df['installment_sqrt'] = np.sqrt(df['installment'])
df['total_acc_sqrt'] = np.sqrt(df['total_acc'])
df['total_payment_sqrt'] = np.sqrt(df['total_payment'])
df['loan_amount_sqrt'] = np.sqrt(df['loan_amount'])

# %% [markdown]
# ## Progress
# some stats about progress in paying off the loan

# %%
df.columns
# Out:
# Index(['address_state', 'emp_title', 'home_ownership', 'issue_date',
#        'last_credit_pull_date', 'last_payment_date', 'loan_status',
#        'next_payment_date', 'purpose', 'verification_status', 'annual_income',
#        'dti', 'installment', 'int_rate', 'loan_amount', 'total_acc',
#        'total_payment', 'emp_years', 'grade_numeric', 'sub_grade_numeric',
#        'issue_year', 'issue_month', 'issue_day', 'issue_weekday',
#        'last_credit_pull_year', 'last_credit_pull_month',
#        'last_credit_pull_day', 'last_credit_pull_weekday', 'last_payment_year',
#        'last_payment_month', 'last_payment_day', 'last_payment_weekday',
#        'next_payment_year', 'next_payment_month', 'next_payment_day',
#        'next_payment_weekday', 'term_months', 'north_south_address',
#        'purpose_clustered', 'daysdiff_issue_pull', 'pull_after_issue',
#        'last_next_diff', 'end_date', 'time_to_last_payment', 'emp_category',
#        'installment_sqrt', 'total_acc_sqrt', 'total_payment_sqrt',
#        'loan_amount_sqrt'],
#       dtype='object')

# %% [markdown]
# procent spłaconego kredytu, stosunek wartości pożyczki do przychodów na przypadający jej okres

# %%
df['payment_progress'] = df['total_payment'] / (df['installment'] * df['term_months'])
df['loan_to_income_full_period'] = df['loan_amount'] / (df['annual_income'] * df['term_months'] / 12)

# %%
df['payment_progress']
# Out:
# 0        0.281074
# 1        0.999878
# 2        0.232025
# 3        0.843293
# 4        0.999979
#            ...
# 38571    0.965183
# 38572    0.916247
# 38573    0.948115
# 38574    0.916052
# 38575    0.947535
# Name: payment_progress, Length: 38576, dtype: float64

# %%
df.payment_progress.max() # jakieś odsetki / zmiany raty? raczej w granicach błędu
# Out:
# 1.2022251267577175

# %%
df.loc[df.loan_status == 'Fully Paid',['payment_progress']].mean() # mniej więcej działa, z pewnymi odchyleniami, np. w związku ze zmianą wysokości raty etc.
# Out:
# payment_progress    0.964844
# dtype: float64

# %%
df['loan_to_income_full_period']
# Out:
# 0        0.016667
# 1        0.020833
# 2        0.080000
# 3        0.021429
# 4        0.014056
#            ...
# 38571    0.048500
# 38572    0.100800
# 38573    0.076923
# 38574    0.013043
# 38575    0.045000
# Name: loan_to_income_full_period, Length: 38576, dtype: float64

# %% [markdown]
# niska korelacja pomiędzy loan_to_income_full_period i dti, więc jest ok

# %%
df.loc[:,['loan_to_income_full_period', 'dti']].corr()
# Out:
#                             loan_to_income_full_period       dti
# loan_to_income_full_period                    1.000000  0.120045
# dti                                           0.120045  1.000000
